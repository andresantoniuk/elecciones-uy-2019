# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pillow

import requests
from PIL import Image
from io import BytesIO
import os
import time

# Add your Computer Vision subscription key and endpoint to your environment variables.
if 'COMPUTER_VISION_SUBSCRIPTION_KEY' in os.environ:
    subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
else:
    print("\nSet the COMPUTER_VISION_SUBSCRIPTION_KEY environment variable.\n**Restart your shell or IDE for changes to take effect.**")
    sys.exit()

if 'COMPUTER_VISION_ENDPOINT' in os.environ:
    endpoint = os.environ['COMPUTER_VISION_ENDPOINT']

text_recognition_url = endpoint + "vision/v2.1/read/core/asyncBatchAnalyze"

# Set image_path to the local path of an image that you want to analyze.
image_path = "actas/acta_prueba.jpg"

# Read the image into a byte array
image_data = open(image_path, "rb").read()

headers = {'Ocp-Apim-Subscription-Key': subscription_key,
           'Content-Type': 'application/octet-stream'}

response = requests.post(
    text_recognition_url, headers=headers, data=image_data)

response.raise_for_status()

print(response)

# The recognized text isn't immediately available, so poll to wait for completion.
analysis = {}
poll = True
while (poll):
    response_final = requests.get(
        response.headers["Operation-Location"], headers=headers)
    analysis = response_final.json()
    print(analysis)
    time.sleep(1)
    if ("recognitionResults" in analysis):
        poll = False
    if ("status" in analysis and analysis['status'] == 'Failed'):
        poll = False


for lines in analysis['recognitionResults'][0]['lines']:
    print(lines['text'])
# Out:
# Requirement already satisfied: pillow in /srv/conda/envs/notebook/lib/python3.7/site-packages (6.2.1)
# <Response [202]>
# {'status': 'Running'}
# {'status': 'Running'}
# {'status': 'Succeeded', 'recognitionResults': [{'page': 1, 'clockwiseOrientation': 359.36, 'width': 4032, 'height': 3024, 'unit': 'pixel', 'lines': [{'boundingBox': [478, 268, 1213, 267, 1213, 317, 479, 319], 'text': 'Comision Receptora de Votos DEPARTAMENTO:', 'words': [{'boundingBox': [484, 272, 632, 270, 633, 317, 486, 316], 'text': 'Comision'}, {'boundingBox': [641, 270, 800, 269, 801, 317, 642, 317], 'text': 'Receptora'}, {'boundingBox': [809, 269, 847, 269, 847, 318, 809, 318], 'text': 'de'}, {'boundingBox': [856, 269, 951, 268, 951, 318, 855, 318], 'text': 'Votos'}, {'boundingBox': [974, 268, 1212, 267, 1210, 319, 974, 318], 'text': 'DEPARTAMENTO:'}]}, {'boundingBox': [180, 322, 1839, 323, 1839, 392, 179, 391], 'text': 'CORTE ELECTORAL ACTA DE ESCRUTINIO |CIRCUITON: 7234', 'words': [{'boundingBox': [188, 341, 279, 338, 279, 384, 189, 384], 'text': 'CORTE'}, {'boundingBox': [287, 338, 456, 333, 457, 386, 287, 384], 'text': 'ELECTORAL', 'confidence': 'Low'}, {'boundingBox': [489, 332, 675, 328, 675, 387, 489, 386], 'text': 'ACTA'}, {'boundingBox': [721, 327, 809, 326, 809, 388, 722, 388], 'text': 'DE'}, {'boundingBox': [855, 325, 1315, 324, 1315, 391, 856, 388], 'text': 'ESCRUTINIO'}, {'boundingBox': [1356, 325, 1623, 329, 1624, 392, 1356, 391], 'text': '|CIRCUITON:', 'confidence': 'Low'}, {'boundingBox': [1670, 330, 1812, 334, 1812, 393, 1670, 393], 'text': '7234', 'confidence': 'Low'}]}, {'bo
# CORTE ELECTORAL ACTA DE ESCRUTINIO |CIRCUITON: 7234
# SERIE ABC
# VOTOS PARTIDO ASAMBLEA POPULAR
# HOJAN
# CANTIDAD EMLERAS
# VOTOS PARTIDO DE LOS TRABAJADORES
# CANTIDAD
# En ..
# HOJAN
# CANTOAD EN LETRAS
# a lion veintisiete dias del mes de octubre de 2019, se procedio a la apertura de la urna
# TOTALDE VOTANTES
# Resulta del numero aquicado en la lista ordinal a
# TOTAL VOTOS NO OBSERVADOS (SOBRES AMARILLOS)
# TOTAL VOTOS OBSERVADOS (SOBRESAZULES) ..
# rubizado renglones.
# TOTAL DE VOTOS
# TOTAL DE VOTOS
# La can idad de sobies encontra dos en la uma ._.. (sino) coincide con el numero de votantes que surge de la lista Ordinal (si no hay
# coincidancias explicar el motto ..
# VOTOS PARTIDO ECOLOGISTA RADICAL INTRANSIGENTE
# Abierios los sotres de votacion NO Observados (amarillos) se encontraron las siguientes hojas de votacion
# WOOTOS AD JD CA DOS ALENA
# MOJAN
# CANTIDAD
# TO W. DEVOTOR
# CANTIDAD EN LETRAS
# RESULTADO PLEBISCITO
# HOJAS POR "SI"
# 123
# CIENTO VEINTITRES
# VOTOS PARTIDO DE LA GENTE
# HOJAM
# CANTIDAD
# EM MUM EROS
# CANTIONO EN LETRAS
# WCTOS AQUOC ADDS AL LEM
# TOTAL DE VCTOS
# VOTOS PARTIDO FRENTE AMPLIO
# HOUA IF
# CANTIDAD
# EN MUKE ROS
# CANTIDAD EN LETRAS
# VOTOS PARTIDO NACIONAL
# HOJAN
# CANTDAD
# CANTIDAD EN LETRAS
# VOTOS PARTIDO VERDE ANIMALISTA
# MOJAN'
# CANTIDAD
# CANTDAD EN LETRA
# MOTOS AD JUDICADDS ALLENA
# TOWN. DEVOTOR
# VOTOS PARTIDO CABILDO ABIERTO
# D AL DE KCTOS
# CANTDAD EN LETRAS
# VOTOS PARTIDO DIGITAL
# HOJAN'
# CANTIDAD
# CANTDAD EN LETHAS
# VOTES NO LO CAOCS AL LAM
# TOTAL DE VO D'S
# RESUMEN DE VOTOS ESCRUTADOS
# Suma de votos de todos los lemas
# +
# Sobres solo con hojas por "Si" (not hop de wilde)
# 123
# +
# Votos en blanco total Sales que
# a wide ni hop spor # '97
# 456
# VOTOS ANUDE CADOS AL LENA
# 789
# Sobres con hojas anuladas en su totalidad
# 723
# TOTAL DE VOROS
# Total de votos no observados (sobres amarillos) co
# 426
# VOTOS PARTIDO COLORADO
# MOJA N
# CANTDAD
# CANTOAD EN LETRAS
# Las hojas arvindas to Aaron por las siguientes caus as
# Los volos adjudication al lama ( son ba co
# OBSERVACIONES
# PRUEBA
# VO ESAD LOCOCALLOW
# TORAL DEVODS
# FIRMAS DE LA COMISION RECEPTORA DE VOTOS
# VOTOS PARTIDO INDEPENDIENTE
# HOJAN
# CANTIDAD
# CANTIDAD EN LETRAS
# Adamacion
# FIRM AS DE LOS DELEGADOS
# VOTOS ACUTI CADOS AL LER
# Fima/ Adandon /C. Civon
# ema / Adaracion /C. CMom
# Fama/Adasdon /C.Civa
# DOWAL DE VOTOS
# TOTAL DE VOTOS
